# %% [markdown]
# <a href="https://colab.research.google.com/github/gunobo/bssm-wintercamp_python/blob/main/%EB%B6%80%EC%82%B0%EC%86%8C%EB%A7%88%EA%B3%A02026%EA%B2%A8%EC%9A%B8%EC%BA%A0%ED%94%8401_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
b = 2
print("바꾸기전값: {},{}".format(a,b))
a,b = b,a
print("바꾸고난값: {},{}".format(a,b))
# Out:
# 바꾸기전값: 1,2
# 바꾸고난값: 2,1

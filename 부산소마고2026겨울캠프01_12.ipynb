# %% [markdown]
# <a href="https://colab.research.google.com/github/gunobo/bssm-wintercamp_python/blob/main/%EB%B6%80%EC%82%B0%EC%86%8C%EB%A7%88%EA%B3%A02026%EA%B2%A8%EC%9A%B8%EC%BA%A0%ED%94%8401_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 개인문제

# %%
# 뭐 만들라했지
# 2진수 입력 받아 -> 10진수로 변환

bin = input("2진수를 입력해주세요(최대 5자리): ")


print("10진수로 변환을 시작합니다...")
if int(bin) >= 111110:
  print("2진수가 6자리 이상입니다!")
else:
  bin2 = str(bin)
  five = int(bin2[0]) * 16
  four = int(bin2[1]) * 8
  three = int(bin2[2]) * 4
  two = int(bin2[3]) * 2
  one = int(bin2[4]) * 1
  result = five + four + three + two + one
  print("변환값은 {}입니다".format(result))
# Out:
# 2진수를 입력해주세요(최대 5자리): 10110
# 10진수로 변환을 시작합니다...
# 변환값은 22입니다

# %%
# 뭐 만들라했지
# 2진수 입력 받아 -> 8진수로 변환

bin = input("2진수를 입력해주세요(소수 불가, 최대 5자리): ")


print("8진수로 변환을 시작합니다...")
def BinToOct(bin):
  if int(bin) >= 111110:
    print("2진수가 6자리 이상입니다!")
  else:
    result10 = 0
    if len(bin) >= 1:
      one = int(bin[-1]) * 1
    if len(bin) >= 2:
      two = int(bin[-2]) * 2
    if len(bin) >= 3:
      three = int(bin[-3]) * 4
    if len(bin) >= 4:
      four = int(bin[-4]) * 8
    if len(bin) >= 5:
      five = int(bin[-5]) * 16

    Dec = one + two + three + four + five

    Oct = ""
    while Dec > 0:
      Oct = str(Dec % 8) + Oct
      Dec //= 8

    print("8진수 변환값은 {}입니다".format(Oct))

bin2 = str(bin)
BinToOct(bin2)
# Out:
# 2진수를 입력해주세요(소수 불가, 최대 5자리): 10110
# 8진수로 변환을 시작합니다...
# 8진수 변환값은 26입니다

# %%
# 보너스문제 거스름돈 문제(반복문 없이)
money = int(input())

cnt = 0

cnt += money // 50000
money %= 50000

cnt += money // 10000
money %= 10000

cnt += money // 5000
money %= 5000

cnt += money // 1000
money %= 1000

cnt += money // 500
money %= 500

cnt += money // 100
money %= 100

cnt += money // 50
money %= 50

cnt += money // 10
money %= 10

print(cnt)
# Out:
# 54520
# 8
